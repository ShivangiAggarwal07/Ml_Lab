# %%
import kagglehub

# Downloading the latest version
path = kagglehub.dataset_download("milobele/sentiment140-dataset-1600000-tweets")

print("Path to dataset files:", path)
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.5), please consider upgrading to the latest version (0.3.6).
# Path to dataset files: /root/.cache/kagglehub/datasets/milobele/sentiment140-dataset-1600000-tweets/versions/1

# %%
#Importing necessary libraries

import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.cluster import KMeans
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score
#warnings
import warnings
warnings.filterwarnings('ignore')
# Text preprocessing
import nltk

# Downloading the 'stopwords' dataset
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
#Importing Dataset
data = pd.read_csv('/root/.cache/kagglehub/datasets/milobele/sentiment140-dataset-1600000-tweets/versions/1/testdata.manual.2009.06.14.csv')

# %%
data
# Out:
#      4      3  Mon May 11 03:17:40 UTC 2009  kindle2           tpryan  \
# 0    4      4  Mon May 11 03:18:03 UTC 2009  kindle2           vcu451
# 1    4      5  Mon May 11 03:18:54 UTC 2009  kindle2           chadfu
# 2    4      6  Mon May 11 03:19:04 UTC 2009  kindle2            SIX15
# 3    4      7  Mon May 11 03:21:41 UTC 2009  kindle2         yamarama
# 4    4      8  Mon May 11 03:22:00 UTC 2009  kindle2     GeorgeVHulme
# ..  ..    ...                           ...      ...              ...
# 492  2  14072  Sun Jun 14 04:31:43 UTC 2009    latex          proggit
# 493  0  14073  Sun Jun 14 04:32:17 UTC 2009    latex           sam33r
# 494  4  14074  Sun Jun 14 04:36:34 UTC 2009    latex  iamtheonlyjosie
# 495  0  14075  Sun Jun 14 21:36:07 UTC 2009     iran        plutopup7
# 496  0  14076  Sun Jun 14 21:36:17 UTC 2009     iran     captain_pete
#
#     @stellargirl I loooooooovvvvvveee my Kindle2. Not that the DX is cool, but the 2 is fantastic in its own right.
# 0    Reading my kindle2...  Love it... Lee childs i...
# 1    Ok, first assesment of the #kindle2 ...it fuck...
# 2    @kenburbary You'll love your Kindle2. I've had...
# 3    @mikefish  Fair enough. But i have the Kindle2...
# 4    @richardebaker no. it is too big. I'm quite ha...
# ..                                                 ...
# 492  Ask Programming: LaTeX or InDesign?: submitted...
# 493  On that note, I hate Word. I hate Pages. I hat...
# 494  Ahhh... back in a *real* text editing environm...
# 495  Trouble in Iran, I see. Hmm. Iran. Iran so far...
# 496  Reading the tweets coming out of Iran... The w...
#
# [497 rows x 6 columns]

# %%
data.head()
# Out:
#    4  3  Mon May 11 03:17:40 UTC 2009  kindle2        tpryan  \
# 0  4  4  Mon May 11 03:18:03 UTC 2009  kindle2        vcu451
# 1  4  5  Mon May 11 03:18:54 UTC 2009  kindle2        chadfu
# 2  4  6  Mon May 11 03:19:04 UTC 2009  kindle2         SIX15
# 3  4  7  Mon May 11 03:21:41 UTC 2009  kindle2      yamarama
# 4  4  8  Mon May 11 03:22:00 UTC 2009  kindle2  GeorgeVHulme
#
#   @stellargirl I loooooooovvvvvveee my Kindle2. Not that the DX is cool, but the 2 is fantastic in its own right.
# 0  Reading my kindle2...  Love it... Lee childs i...
# 1  Ok, first assesment of the #kindle2 ...it fuck...
# 2  @kenburbary You'll love your Kindle2. I've had...
# 3  @mikefish  Fair enough. But i have the Kindle2...
# 4  @richardebaker no. it is too big. I'm quite ha...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 497 entries, 0 to 496
# Data columns (total 6 columns):
#  #   Column                                                                                                           Non-Null Count  Dtype
# ---  ------                                                                                                           --------------  -----
#  0   4                                                                                                                497 non-null    int64
#  1   3                                                                                                                497 non-null    int64
#  2   Mon May 11 03:17:40 UTC 2009                                                                                     497 non-null    object
#  3   kindle2                                                                                                          497 non-null    object
#  4   tpryan                                                                                                           497 non-null    object
#  5   @stellargirl I loooooooovvvvvveee my Kindle2. Not that the DX is cool, but the 2 is fantastic in its own right.  497 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 23.4+ KB

# %%
data.columns = ['polarity', 'id', 'date', 'query', 'user', 'tweet']

# %%
# Selecting the relevant columns
data = data[['polarity', 'tweet']]

# %%
#Now Mapping polarity to categories

data['polarity'] = data['polarity'].map({0: 'negative', 2: 'neutral', 4: 'positive'})

# %% [markdown]
# # Data cleaning

# %%
def clean_text(text):
    text = re.sub(r'http\S+', '', text)  # Removing URLs
    text = re.sub(r'@\w+', '', text)    # Removing mentions
    text = re.sub(r'#', '', text)        # Removing hashtags symbol
    text = re.sub(r'[^a-zA-Z\s]', '', text)  # Removing special characters
    text = text.lower().strip()         # Converting to lowercase
    return text

data['cleaned_tweet'] = data['tweet'].apply(clean_text)

# %%
# Text preprocessing
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

# %%
# Downloading the 'wordnet' dataset
nltk.download('wordnet') # Download the wordnet dataset

# Text preprocessing
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

# Downloading the 'punkt_tab' data package
nltk.download('punkt_tab')

def preprocess_text(text):
    words = word_tokenize(text)
    words = [lemmatizer.lemmatize(word) for word in words if word not in stop_words]
    return ' '.join(words)

data['processed_tweet'] = data['cleaned_tweet'].apply(preprocess_text)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
# Visualize=ing the sentiment distribution
sns.countplot(x='polarity', data=data, palette='viridis')
plt.title('Sentiment Distribution')
plt.show()

# %%
# Generating the WordCloud for each sentiment
for sentiment in ['negative', 'neutral', 'positive']:
    text = ' '.join(data[data['polarity'] == sentiment]['processed_tweet'])
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.title(f'WordCloud for {sentiment} Sentiment')
    plt.show()

# %%
# Train test split
X = data['processed_tweet']
y = data['polarity']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=100)

# %%
# Feature extraction using TF-IDF
vectorizer = TfidfVectorizer(max_features=5000)
X_train_tfidf = vectorizer.fit_transform(X_train)
X_test_tfidf = vectorizer.transform(X_test)

# %%
# Defining models and parameters
models = {
    'Logistic Regression': LogisticRegression(max_iter=1000),
    'SVM': SVC(),
    'Random Forest': RandomForestClassifier()
}

# %%
params = {
    'Logistic Regression': {'C': [0.1, 1, 10]},
    'SVM': {'C': [0.1, 1, 10], 'kernel': ['linear', 'rbf']},
    'Random Forest': {'n_estimators': [50, 100, 200], 'max_depth': [None, 10, 20]}
}

# %%
# Performing GridSearchCV for each model
best_models = {}
for model_name in models:
    print(f"Tuning {model_name}...")
    grid = GridSearchCV(models[model_name], params[model_name], cv=3, scoring='f1_weighted', n_jobs=-1)
    grid.fit(X_train_tfidf, y_train)
    best_models[model_name] = grid.best_estimator_
    print(f"Best parameters for {model_name}: {grid.best_params_}")
# Out:
# Tuning Logistic Regression...
# Best parameters for Logistic Regression: {'C': 10}
# Tuning SVM...
# Best parameters for SVM: {'C': 10, 'kernel': 'linear'}
# Tuning Random Forest...
# Best parameters for Random Forest: {'max_depth': None, 'n_estimators': 50}

# %%
# Evaluating each best model
for model_name, model in best_models.items():
    print(f"\nEvaluating {model_name}...")
    y_pred = model.predict(X_test_tfidf)
    accuracy = accuracy_score(y_test, y_pred) # Calculating accuracy as well
    print(f"Accuracy: {accuracy:.4f}")

    print("Classification Report:")
    print(classification_report(y_test, y_pred))
# Out:
# Evaluating Logistic Regression...
# Accuracy: 0.6533
# Classification Report:
#               precision    recall  f1-score   support
#
#     negative       0.63      0.79      0.70        47
#      neutral       0.56      0.46      0.51        39
#     positive       0.73      0.67      0.70        64
#
#     accuracy                           0.65       150
#    macro avg       0.64      0.64      0.63       150
# weighted avg       0.65      0.65      0.65       150
#
#
# Evaluating SVM...
# Accuracy: 0.6333
# Classification Report:
#               precision    recall  f1-score   support
#
#     negative       0.61      0.77      0.68        47
#      neutral       0.55      0.46      0.50        39
#     positive       0.71      0.64      0.67        64
#
#     accuracy                           0.63       150
#    macro avg       0.62      0.62      0.62       150
# weighted avg       0.63      0.63      0.63       150
#
#
# Evaluating Random Forest...
# Accuracy: 0.6667
# Classification Report:
#               precision    recall  f1-score   support
#
#     negative       0.67      0.66      0.67        47
#      neutral       0.59      0.56      0.58        39
#     positive       0.70      0.73      0.72        64
#
#     accuracy                           0.67       150
#    macro avg       0.66      0.65      0.65       150
# weighted avg       0.67      0.67      0.67       150

# %%
# Creating Confusion Matrix for the best model
best_model = best_models['Logistic Regression']  # As Logistic Regression as the best
conf_matrix = confusion_matrix(y_test, best_model.predict(X_test_tfidf))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=best_model.classes_, yticklabels=best_model.classes_)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
# Topic Modeling with LDA

vectorizer_lda = CountVectorizer(max_features=1000, stop_words='english')
X_lda = vectorizer_lda.fit_transform(data['processed_tweet'])
lda = LatentDirichletAllocation(n_components=5, random_state=42)
lda.fit(X_lda)
# Out:
# LatentDirichletAllocation(n_components=5, random_state=42)

# %%
# Displaying the topics
for idx, topic in enumerate(lda.components_):
    print(f"Topic {idx+1}: ", [vectorizer_lda.get_feature_names_out()[i] for i in topic.argsort()[-10:]])
# Out:
# Topic 1:  ['got', 'internet', 'cable', 'gm', 'love', 'lebron', 'rt', 'nike', 'warner', 'time']
# Topic 2:  ['silverstein', 'goodby', 'day', 'nike', 'gm', 'car', 'im', 'great', 'good', 'new']
# Topic 3:  ['like', 'good', 'stanford', 'dentist', 'atampt', 'today', 'francisco', 'san', 'come', 'hate']
# Topic 4:  ['eating', 'movie', 'book', 'got', 'safeway', 'jquery', 'new', 'love', 'museum', 'night']
# Topic 5:  ['new', 'video', 'look', 'kindle', 'time', 'read', 'using', 'good', 'api', 'twitter']

# %%
# Clustering with K Means
kmeans = KMeans(n_clusters= 10, random_state=100)
kmeans_labels = kmeans.fit_predict(X_train_tfidf)

# %%
# Visualizing clustering results
sns.scatterplot(x=X_train_tfidf.toarray()[:, 0], y=X_train_tfidf.toarray()[:, 1], hue=kmeans_labels, palette='viridis')
plt.title('KMeans Clustering')
plt.show()

# %%
from sklearn.cluster import KMeans

# Assuming X_train_tfidf is our TF-IDF matrix
num_clusters = 10
kmeans = KMeans(n_clusters=num_clusters, random_state=100)
cluster_labels = kmeans.fit_predict(X_train_tfidf)

# Creating a new DataFrame for the training data with cluster labels
clustered_data = pd.DataFrame({'processed_tweet': X_train, 'cluster_kmeans': cluster_labels})

data = pd.merge(data, clustered_data[['processed_tweet', 'cluster_kmeans']], on='processed_tweet', how='left', suffixes=('', '_y'))

# Exploring the clusters
for i in range(num_clusters):
    print(f"Cluster {i}:")
    # Accessing cluster column
    cluster_tweets = data[data['cluster_kmeans'] == i]['processed_tweet']
    print(cluster_tweets.sample(10))  # Printing 10 sample tweets from the cluster
# Out:
# Cluster 0:
# 377       old cocacola guy gm board stupid heck tcot ala
# 376    never buy government motor vehicle recently dr...
# 372    shame gm forced make car white house think sel...
# 158                    gm ceo china continue key partner
# 220    youre harassed call car warranty changing numb...
# 89     burning cash chrysler gm stop financial tsunam...
# 380    hear gm thing angry get billion wasted bullshi...
# 138        tell giving gm use program support unemployed
# 131      night museum wolverine junk food perfect monday
# 159                                   rt time buy gm car
# Name: processed_tweet, dtype: object
# Cluster 1:
# 256    lebron done nba probably greater kobe like u s...
# 252        lebron cool like personalityhe good character
# 122    viral marketing fail acia pill brand oughta ge...
# 402                         gm file bankruptcy good sign
# 288                         star trek good everyone said
# 340                         exam went good prayer worked
# 253            watching lebron highlight damn nigga good
# 403                            yankee mets lost good day
# 38     bit crazy steep learning curve lyx really good...
# 461     today good day dislike atampt vote office indeed
# Name: processed_tweet, dtype: object
# Cluster 2:
# 348      rt awesome jquery reference book coda webdesign
# 71                     rt told nike layoff started today
# 415    rt ca merceds water bottled safeway resold pro...
# 316    picked new canon dit beautiful prepare serious...
# 105         really liked learning jquery book worth look
# 106                                jquery ui book review
# 109       rt goodby silverstein new site enjoy nice find
# 289             loving new malcolm gladwell book outlier
# 439        argghhhh wont jquery appear safari bad safari
# 442    im ready drop pretense forever love jquery wan...
# Name: processed_tweet, dtype: object
# Cluster 3:
# 394    rt upside time warner unhelpful phone operator...
# 306    wolfram alpha suck even researcher information...
# 271                              itchy back dont ya hate
# 408                     hate dentistwho invented anyways
# 14     lebron best athlete generation time basketball...
# 386     wftb joining bit late connection boo time warner
# 145    time warner devil worst possible time internet go
# 384    whoever running time warner need repeatedly ra...
# 407                                   hate going dentist
# 147    time warner really pick worst time work want g...
# Name: processed_tweet, dtype: object
# Cluster 4:
# 240                                 twitter apr apps yet
# 299                                      use twitter api
# 60                              playing curl twitter api
# 302                                  testing twitter api
# 443    cold looking google chartvisualization api fou...
# 233    wtf point deleting tweet still found summize s...
# 63                    twitter api slow client arent good
# 485    twitter stock buzz aapl esf spy spx palm updat...
# 300                              curse twitter api limit
# 59     playing twitter api sound fun may need take cl...
# Name: processed_tweet, dtype: object
# Cluster 5:
# 245              obamas speech pretty awesome last night
# 248    obamas got joke haha got watch bit dinner spee...
# 34                omg bored amp tattoooos itchy help aha
# 15     talking guy last night telling die hard spur f...
# 399                       weird piano guitar house china
# 281           bonjour san francisco back hurt last night
# 107    interesting ad adobe goodby silverstein amp pa...
# 336                mcdonalds dinner goooood big mac meal
# 11     house correspondent dinner last night whoopi b...
# 9      check video president obama white house corres...
# Name: processed_tweet, dtype: object
# Cluster 6:
# 65                                      scrapbooking nic
# 251                                          lebron best
# 112                                               zomg g
# 411    first dentist appointment year wednesday possibly
# 314                hey bud np love although id love mkii
# 44                             san francisco bay breaker
# 416      dropped broccoli walking home safeway depressed
# 291    malcolm gladwell genius tricking people realiz...
# 282                             breaker san francisco ca
# 182             safeway supermarketing via mobile coupon
# Name: processed_tweet, dtype: object
# Cluster 7:
# 186                                eating watching movie
# 431                      eating dinner meat chip risotto
# 425    saved money opting grocery store trip stocking...
# 187                                       eating sashimi
# 451    mean im notre dame good school id closer dan i...
# 189                                          eating cake
# 205    according create school notre dame receiver nc...
# 156    myfoxdc barrie student back trip china silver ...
# 427                              eating breakfast school
# 185                 normal weight get normal eating blog
# Name: processed_tweet, dtype: object
# Cluster 8:
# 246                  reading bill clinton fail obama win
# 81     great stanford course thanks making available ...
# 484    monday already iran may implode kitchen disast...
# 477    cant wait great american food music festival s...
# 244           like guy barack obama show funny side gtgt
# 332    nancy pelosi gave worst commencement speech iv...
# 119        hi anyone great source advice viral marketing
# 358                 awesome viral marketing funny people
# 487                                   bobby flay joining
# 475    excited seeing bobby flay guy fieri tomorrow g...
# Name: processed_tweet, dtype: object
# Cluster 9:
# 437    look awful lot like one nike private jetsim sayin
# 192    iphone may get radio tagging nike recentlyrele...
# 307                                         nike factory
# 433          nike sb blazer high acg custom brad douglas
# 230                 yay glad got phone still damn atampt
# 190    love dwight howard vitamin water commercial wi...
# 462    got wave sandbox invite extra excited bad clas...
# 432                     got new pair nike shoe pic later
# 193        lovin nike already thats running spot bedroom
# 73        way im totally inspired freaky nike commercial
# Name: processed_tweet, dtype: object

# %% [markdown]
# Our evaluation showed that Logistic Regression outperformed SVM and Random Forest in terms of balanced F1-score across sentiment classes. Clustering and topic modeling provided valuable insights into sentiment distribution and key themes. While the analysis effectively demonstrated sentiment analysis techniques, further improvements could be achieved through fine-tuning and dimensionality reduction to enhance cluster visualization.
